# %% [markdown]
# # Importando as bibliotecas Python necessárias

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data= {'Nome':["ana",'julia','maria','jose'],'Ano':[2000,2002,2004,2008]}

# %%
df=pd.DataFrame(data)

# %%
df['Altura']=np.linspace(1.45,1.90,4)

# %%
df
# Out:
#     Nome   Ano  Altura
# 0    ana  2000    1.45
# 1  julia  2002    1.60
# 2  maria  2004    1.75
# 3   jose  2008    1.90

# %% [markdown]
# # Leitura de arquivos

# %%
#df=pd.read_csv("/content/DataRelease/Pantheon+_Data/4_DISTANCES_AND_COVAR/Pantheon+SH0ES.dat",sep=r'\s+')

# %%
# !git clone https://github.com/PantheonPlusSH0ES/DataRelease.git
# Out:
# fatal: destination path 'DataRelease' already exists and is not an empty directory.
